# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('Industrial.xls', sheet_name='Industrial')
data
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %%
data.loc[42, 'Name of the Student/Faculty']='Marathe Jaitirth Patil'

# %%
data
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %%
data.to_csv('Industrial.csv')

# %%
data1=data.loc[42,'Name of the Student/Faculty']

# %%
data1
# Out:
# 'Marathe Jaitirth Patil'

# %%
data1=data.loc[42,'Name of the Student/Faculty']='Marathe Jaitirth Patil'

# %%
data1
# Out:
# 'Marathe Jaitirth Patil'

# %%
data2=data.copy()
data2
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %%
data2.loc[42, 'Name of the Student/Faculty']='Student'

# %%
data2
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %%
data.to_csv('new.csv')

# %%
data2
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %% [markdown]
# skiprows

# %%
x=pd.read_excel('Industrial.xls', skiprows=[2,3])
x #it will skip the selected rows
# Out:
#              Timestamp                    Email Address  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 2   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 3   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 4   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 5   9-24-2023 12:25:37            manasorpe36@gmail.com
# 6   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 7   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 8   9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 9   9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 10  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 11  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 12   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 13  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# 14  9-25-2023 10:41:57        amogh.korde1@adypu.edu.in
# 15  9-25-2023 15:54:33            ayushawhale@gmail.com
# ...

# %%
data2.dtypes
# Out:
# Timestamp                              object
# Email Address                          object
# Name of the Student/Faculty            object
# Mobile No. (10 Digits)                 object
# Date of Birth                  datetime64[ns]
# Age                                     int64
# Gender                                 object
# Course                                 object
# Program                                object
# Semester                               object
# Decalartion                            object
# dtype: object

# %%
x=pd.read_csv('Industrial.csv', index_col="Timestamp")
x
# Out:
#                     Unnamed: 0                    Email Address  \
# Timestamp
# 9-24-2023 13:28:57           0        gayatri.pise@adypu.edu.in
# 9-24-2023 13:32:37           1          rinapatil2324@gmail.com
# 9-25-2023 10:58:59           2       sakshimhaske2903@gmail.com
# 9-25-2023 11:26:53           3   anuksha.mhalankar@adypu.edu.in
# 9-25-2023 16:20:47           4           nehagunjal04@gmail.com
# 9-25-2023 17:21:13           5          umme.ahmed@adypu.edu.in
# 9-25-2023 19:03:18           6     vaishnavi.joshi@adypu.edu.in
# 9-24-2023 12:25:37           7            manasorpe36@gmail.com
# 9-24-2023 13:56:13           8          prathameshjd7@gmail.com
# 9-24-2023 14:10:21           9        Omkar.chavan@adypu.edu.in
# 9-24-2023 14:39:25          10        atharv.joshi@adypu.edu.in
# 9-24-2023 16:26:09          11     abhishek.mourya@adypu.edu.in
# 9-24-2023 16:28:49          12    samarthdeshmukh7558@gmail.com
# ...

# %%
x=pd.read_excel('Industrial.xls', header=None, skiprows=1, names=["col1","col2","col3","col4","col5","col6","col7","col8","col9","col10","col11"])
x
# Out:
#                   col1                             col2  \
# 0   9-24-2023 13:28:57        gayatri.pise@adypu.edu.in
# 1   9-24-2023 13:32:37          rinapatil2324@gmail.com
# 2   9-25-2023 10:58:59       sakshimhaske2903@gmail.com
# 3   9-25-2023 11:26:53   anuksha.mhalankar@adypu.edu.in
# 4   9-25-2023 16:20:47           nehagunjal04@gmail.com
# 5   9-25-2023 17:21:13          umme.ahmed@adypu.edu.in
# 6   9-25-2023 19:03:18     vaishnavi.joshi@adypu.edu.in
# 7   9-24-2023 12:25:37            manasorpe36@gmail.com
# 8   9-24-2023 13:56:13          prathameshjd7@gmail.com
# 9   9-24-2023 14:10:21        Omkar.chavan@adypu.edu.in
# 10  9-24-2023 14:39:25        atharv.joshi@adypu.edu.in
# 11  9-24-2023 16:26:09     abhishek.mourya@adypu.edu.in
# 12  9-24-2023 16:28:49    samarthdeshmukh7558@gmail.com
# 13  9-24-2023 20:13:48          harshmakadiya11@ail.com
# 14   9-25-2023 7:23:37       devesh.pandey@adypu.edu.in
# 15  9-25-2023 10:40:25    ushnish.bhowmik1@adypu.edu.in
# ...

# %%
x.loc[[3,4],['col3']] #prints required rows with columns
# Out:
#                   col3
# 3   Anushka Mhalankar
# 4  Neha Suresh Gunjal

# %%
x.dtypes
# Out:
# col1             object
# col2             object
# col3             object
# col4             object
# col5     datetime64[ns]
# col6              int64
# col7             object
# col8             object
# col9             object
# col10            object
# col11            object
# dtype: object

# %%
x.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9',
#        'col10', 'col11'],
#       dtype='object')
